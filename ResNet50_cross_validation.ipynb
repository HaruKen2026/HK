# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir output_ResNet50/logs

# %%
import numpy as np
import os
import glob
import shutil
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import ResNet50
import time
from tensorflow.keras.callbacks import TensorBoard
import datetime

# %%
# Record the start time of the process
start_time = time.time()

# Parameter settings
class_num = 2  # Number of classes (male: 0, female: 1)
epochs = 1000  # Number of training epochs
batch_size = 32  # Batch size
COLOR_CHANNEL = 3  # 3 for RGB images, 1 for grayscale
INPUT_IMAGE_SIZE = 224  # Input image size

# %%
# Folder paths
male_folder = ''
female_folder = ''
id_image_folder = ''
output_folder = ''

# Create folders to save images with IDs
os.makedirs(id_image_folder, exist_ok=True)
male_id_folder = os.path.join(id_image_folder, 'male')
female_id_folder = os.path.join(id_image_folder, 'female')
os.makedirs(male_id_folder, exist_ok=True)
os.makedirs(female_id_folder, exist_ok=True)

# Load images and assign labels
image_data = []
labels = []
image_paths = []  # List to keep IDs of each image

# Load images from the male_hara folder and assign male labels (0)
male_images = glob.glob(f"{male_folder}/*.jpg")
for idx, file in enumerate(male_images):
    img = load_img(file, color_mode="rgb", target_size=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE))
    img_array = img_to_array(img)
    filename = f"male_{idx+1}.jpg"
    img.save(os.path.join(male_id_folder, filename))
    image_data.append(img_array)
    labels.append(0)  # Use 0 as the label for males
    image_paths.append(filename)  # Add a number to male image IDs

# Load images from the female_hara folder and assign female labels (1)
female_images = glob.glob(f"{female_folder}/*.jpg")
for idx, file in enumerate(female_images):
    img = load_img(file, color_mode="rgb", target_size=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE))
    img_array = img_to_array(img)
    filename = f"female_{idx+1}.jpg"
    img.save(os.path.join(female_id_folder, filename))
    image_data.append(img_array)
    labels.append(1)  # Use 1 as the label for females
    image_paths.append(filename)  # Add a number to female image IDs

# Convert to NumPy arrays
image_data = np.array(image_data)
labels = np.array(labels)

# Normalize images to the range [0, 1]
image_data = image_data.astype('float32')
image_data /= 255.0

# Convert labels to one-hot encoding
labels = to_categorical(labels, class_num)

# Output the number of loaded images
print(f"Male images: {len(male_images)}")
print(f"Female images: {len(female_images)}")
print(f"Total images: {len(male_images) + len(female_images)}")
# Out:
# Male images: 60
# Female images: 60
# Total images: 120

# %%
# Data splitting settings
sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

# Arrays to store results
result = []
f1_scores = []

# Log directory for TensorBoard
log_dir = os.path.join(output_folder, "logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
os.makedirs(log_dir, exist_ok=True)

# Process for each fold
for fold, (train_index, test_index) in enumerate(sss.split(image_data, np.argmax(labels, axis=1))):
    # Create folder for the fold
    fold_folder = os.path.join(output_folder, f'fold_{fold+1}')
    os.makedirs(fold_folder, exist_ok=True)

    # TensorBoard settings
    tensorboard_callback = TensorBoard(log_dir=os.path.join(log_dir, f"fold_{fold+1}"), histogram_freq=1)
    
    # Create folders to save training and testing images
    train_folder = os.path.join(fold_folder, 'train_images')
    test_folder = os.path.join(fold_folder, 'test_images')
    os.makedirs(train_folder, exist_ok=True)
    os.makedirs(test_folder, exist_ok=True)

    # Copy and save training and testing images
    for idx in train_index:
        src_path = os.path.join(id_image_folder, 'male' if labels[idx][0] == 1 else 'female', image_paths[idx])
        shutil.copy(src_path, os.path.join(train_folder, image_paths[idx]))
    for idx in test_index:
        src_path = os.path.join(id_image_folder, 'male' if labels[idx][0] == 1 else 'female', image_paths[idx])
        shutil.copy(src_path, os.path.join(test_folder, image_paths[idx]))
        
    # Build the model
    ResNet50_base = ResNet50(weights='imagenet', include_top=False, 
                             input_shape=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE, COLOR_CHANNEL))
    x = GlobalAveragePooling2D()(ResNet50_base.output)
    x = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs=ResNet50_base.input, outputs=x)

    # Compile the model
    model.compile(optimizer=SGD(learning_rate=0.01), 
                  loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

    # Training
    history = model.fit(image_data[train_index], labels[train_index],
                        batch_size=batch_size, epochs=epochs, verbose=1, validation_split=0.1, callbacks=[tensorboard_callback])

    # Evaluate on test data
    test_score = model.evaluate(image_data[test_index], labels[test_index], verbose=1)
    result.append(test_score[1] * 100)

    # Calculate F1 score
    y_pred = model.predict(image_data[test_index])
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(labels[test_index], axis=1)
    f1 = f1_score(y_test_classes, y_pred_classes, average='weighted')  # Calculate F1 score with weighted average
    f1_scores.append(f1)
    print(f"Fold {fold+1} - Accuracy: {test_score[1] * 100:.3f}%, F1 Score: {f1:.4f}")

    # Save the model
    model.save(os.path.join(fold_folder, f'model_fold_{fold+1}.h5'))

    # Save training history
    plt.figure()
    plt.plot(range(epochs), history.history['loss'], label='Train loss')
    plt.plot(range(epochs), history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig(os.path.join(fold_folder, 'loss_plot.png'))
    plt.close()

    plt.figure()
    plt.plot(range(epochs), history.history['accuracy'], label='Train Accuracy')
    plt.plot(range(epochs), history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig(os.path.join(fold_folder, 'accuracy_plot.png'))
    plt.close()

    # Save confusion matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['male', 'female'])
    disp.plot(cmap='Greens', values_format='d')
    plt.savefig(os.path.join(fold_folder, 'confusion_matrix.png'))
    plt.close()

# Aggregate and display/save overall results
summary_path = os.path.join(output_folder, 'result_summary.txt')
with open(summary_path, 'w') as f:
    # Output and save results for each fold
    for i, (score, f1) in enumerate(zip(result, f1_scores), start=1):
        result_text = f'No.{i} test score = {score:.3f} %, F1 Score = {f1:.4f}'
        f.write(result_text + '\n')
        print(result_text)

    # Calculate and output/save average scores
    average_score = sum(result) / len(result)
    average_f1 = sum(f1_scores) / len(f1_scores)
    average_text = f'average score = {average_score:.3f} %, average F1 Score = {average_f1:.4f}'
    f.write(average_text + '\n')
    print(average_text)

# Record the end time of the process and calculate the elapsed time
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Total processing time: {elapsed_time:.2f} seconds")
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 13s 778ms/step - loss: 0.5777 - accuracy: 0.6977 - val_loss: 1.0964 - val_accuracy: 0.2000
# Epoch 2/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.8497 - val_accuracy: 0.2000
# Epoch 3/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.5146 - val_accuracy: 0.8000
# Epoch 4/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5803 - val_accuracy: 0.8000
# Epoch 5/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.7139 - val_accuracy: 0.8000
# Epoch 6/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.4822e-04 - accuracy: 1.0000 - val_loss: 0.7259 - val_accuracy: 0.8000
# Epoch 7/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.0455e-04 - accuracy: 1.0000 - val_loss: 0.7321 - val_accuracy: 0.8000
# Epoch 8/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.3371e-04 - accuracy: 1.0000 - val_loss: 0.7541 - val_accuracy: 0.8000
# Epoch 9/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.1803e-04 - accuracy: 1.0000 - val_loss: 0.7687 - val_accuracy: 0.8000
# Epoch 10/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.2620e-04 - accuracy: 1.0000 - val_loss: 0.7733 - val_accuracy: 0.8000
# Epoch 11/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 5.9791e-05 - accuracy: 1.0000 - val_loss: 0.7605 - val_accuracy: 0.8000
# Epoch 12/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0638e-04 - accuracy: 1.0000 - val_loss: 0.7454 - val_accuracy: 0.8000
# Epoch 13/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 5.3133e-05 - accuracy: 1.0000 - val_loss: 0.7293 - val_accuracy: 0.8000
# Epoch 14/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.9039e-05 - accuracy: 1.0000 - val_loss: 0.7275 - val_accuracy: 0.8000
# Epoch 15/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.0200e-05 - accuracy: 1.0000 - val_loss: 0.7382 - val_accuracy: 0.8000
# Epoch 16/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.9908e-05 - accuracy: 1.0000 - val_loss: 0.7437 - val_accuracy: 0.8000
# Epoch 17/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 5.7198e-05 - accuracy: 1.0000 - val_loss: 0.7371 - val_accuracy: 0.8000
# Epoch 18/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.2914e-05 - accuracy: 1.0000 - val_loss: 0.7460 - val_accuracy: 0.8000
# Epoch 19/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.3738e-04 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.8000
# Epoch 20/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 4.4530e-05 - accuracy: 1.0000 - val_loss: 0.7678 - val_accuracy: 0.8000
# Epoch 21/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 4.4171e-05 - accuracy: 1.0000 - val_loss: 0.7382 - val_accuracy: 0.8000
# Epoch 22/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0481e-04 - accuracy: 1.0000 - val_loss: 0.7074 - val_accuracy: 0.8000
# Epoch 23/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 3.9042e-05 - accuracy: 1.0000 - val_loss: 0.6585 - val_accuracy: 0.8000
# Epoch 24/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 9.6390e-06 - accuracy: 1.0000 - val_loss: 0.5927 - val_accuracy: 0.8000
# Epoch 25/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.7890e-05 - accuracy: 1.0000 - val_loss: 0.5460 - val_accuracy: 0.8000
# Epoch 26/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.2217e-04 - accuracy: 1.0000 - val_loss: 0.5251 - val_accuracy: 0.8000
# Epoch 27/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.3177e-05 - accuracy: 1.0000 - val_loss: 0.5151 - val_accuracy: 0.8000
# Epoch 28/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 5.0525e-06 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8000
# Epoch 29/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.5077e-06 - accuracy: 1.0000 - val_loss: 0.5137 - val_accuracy: 0.8000
# Epoch 30/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.9320e-06 - accuracy: 1.0000 - val_loss: 0.5130 - val_accuracy: 0.8000
# Epoch 31/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 5.7607e-06 - accuracy: 1.0000 - val_loss: 0.5071 - val_accuracy: 0.8000
# Epoch 32/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.4892e-05 - accuracy: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.8000
# Epoch 33/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.6702e-05 - accuracy: 1.0000 - val_loss: 0.5068 - val_accuracy: 0.8000
# Epoch 34/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.5545e-05 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.8000
# Epoch 35/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0561e-05 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.8000
# Epoch 36/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 7.3353e-06 - accuracy: 1.0000 - val_loss: 0.4996 - val_accuracy: 0.8000
# Epoch 37/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.2151e-05 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.8000
# Epoch 38/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 9.3632e-06 - accuracy: 1.0000 - val_loss: 0.5066 - val_accuracy: 0.8000
# Epoch 39/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.1634e-05 - accuracy: 1.0000 - val_loss: 0.5146 - val_accuracy: 0.8000
# Epoch 40/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 5.2077e-06 - accuracy: 1.0000 - val_loss: 0.5249 - val_accuracy: 0.8000
# Epoch 41/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.9501e-05 - accuracy: 1.0000 - val_loss: 0.5408 - val_accuracy: 0.8000
# Epoch 42/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.0558e-06 - accuracy: 1.0000 - val_loss: 0.5590 - val_accuracy: 0.8000
# Epoch 43/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.7564e-06 - accuracy: 1.0000 - val_loss: 0.5779 - val_accuracy: 0.8000
# Epoch 44/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 8.8101e-06 - accuracy: 1.0000 - val_loss: 0.5946 - val_accuracy: 0.8000
# Epoch 45/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.2930e-06 - accuracy: 1.0000 - val_loss: 0.6064 - val_accuracy: 0.8000
# Epoch 46/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.9215e-05 - accuracy: 1.0000 - val_loss: 0.6098 - val_accuracy: 0.8000
# Epoch 47/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 7.8163e-06 - accuracy: 1.0000 - val_loss: 0.6105 - val_accuracy: 0.8000
# Epoch 48/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.2369e-05 - accuracy: 1.0000 - val_loss: 0.6129 - val_accuracy: 0.8000
# Epoch 49/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.5619e-06 - accuracy: 1.0000 - val_loss: 0.6124 - val_accuracy: 0.8000
# Epoch 50/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.3172e-05 - accuracy: 1.0000 - val_loss: 0.6155 - val_accuracy: 0.8000
# Epoch 51/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 5.1589e-05 - accuracy: 1.0000 - val_loss: 0.6235 - val_accuracy: 0.8000
# Epoch 52/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.4944e-05 - accuracy: 1.0000 - val_loss: 0.6357 - val_accuracy: 0.8000
# Epoch 53/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.3499e-05 - accuracy: 1.0000 - val_loss: 0.6471 - val_accuracy: 0.8000
# Epoch 54/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 8.6868e-06 - accuracy: 1.0000 - val_loss: 0.6582 - val_accuracy: 0.8000
# Epoch 55/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 8.8829e-04 - accuracy: 1.0000 - val_loss: 0.6667 - val_accuracy: 0.8000
# Epoch 56/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.3623e-06 - accuracy: 1.0000 - val_loss: 0.6794 - val_accuracy: 0.8000
# Epoch 57/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.8885e-06 - accuracy: 1.0000 - val_loss: 0.6954 - val_accuracy: 0.8000
# Epoch 58/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.6050e-05 - accuracy: 1.0000 - val_loss: 0.7070 - val_accuracy: 0.8000
# Epoch 59/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.0596e-05 - accuracy: 1.0000 - val_loss: 0.7166 - val_accuracy: 0.8000
# Epoch 60/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.1623e-06 - accuracy: 1.0000 - val_loss: 0.7270 - val_accuracy: 0.8000
# Epoch 61/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.9152e-06 - accuracy: 1.0000 - val_loss: 0.7449 - val_accuracy: 0.8000
# Epoch 62/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.1113e-06 - accuracy: 1.0000 - val_loss: 0.7614 - val_accuracy: 0.8000
# Epoch 63/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.5645e-06 - accuracy: 1.0000 - val_loss: 0.7798 - val_accuracy: 0.8000
# Epoch 64/1000
# 3/3 [==============================] - 0s 101ms/step - loss: 2.0274e-05 - accuracy: 1.0000 - val_loss: 0.8067 - val_accuracy: 0.8000
# Epoch 65/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 4.2873e-06 - accuracy: 1.0000 - val_loss: 0.8390 - val_accuracy: 0.8000
# Epoch 66/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.3579e-05 - accuracy: 1.0000 - val_loss: 0.8752 - val_accuracy: 0.8000
# Epoch 67/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 5.0511e-06 - accuracy: 1.0000 - val_loss: 0.9156 - val_accuracy: 0.8000
# Epoch 68/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.7019e-06 - accuracy: 1.0000 - val_loss: 0.9556 - val_accuracy: 0.8000
# Epoch 69/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.0038e-06 - accuracy: 1.0000 - val_loss: 0.9940 - val_accuracy: 0.8000
# Epoch 70/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 7.4989e-06 - accuracy: 1.0000 - val_loss: 1.0342 - val_accuracy: 0.8000
# Epoch 71/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 7.8452e-06 - accuracy: 1.0000 - val_loss: 1.0701 - val_accuracy: 0.8000
# Epoch 72/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0185e-05 - accuracy: 1.0000 - val_loss: 1.1079 - val_accuracy: 0.8000
# Epoch 73/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.3642e-05 - accuracy: 1.0000 - val_loss: 1.1432 - val_accuracy: 0.8000
# Epoch 74/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.4546e-05 - accuracy: 1.0000 - val_loss: 1.1759 - val_accuracy: 0.8000
# Epoch 75/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.3387e-05 - accuracy: 1.0000 - val_loss: 1.2084 - val_accuracy: 0.8000
# Epoch 76/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 5.1952e-06 - accuracy: 1.0000 - val_loss: 1.2343 - val_accuracy: 0.8000
# Epoch 77/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 8.3080e-06 - accuracy: 1.0000 - val_loss: 1.2542 - val_accuracy: 0.8000
# Epoch 78/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.5097e-05 - accuracy: 1.0000 - val_loss: 1.2703 - val_accuracy: 0.8000
# Epoch 79/1000
# 3/3 [==============================] - 0s 108ms/step - loss: 2.9539e-06 - accuracy: 1.0000 - val_loss: 1.2908 - val_accuracy: 0.8000
# Epoch 80/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.2802e-05 - accuracy: 1.0000 - val_loss: 1.3134 - val_accuracy: 0.8000
# Epoch 81/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 4.6976e-06 - accuracy: 1.0000 - val_loss: 1.3321 - val_accuracy: 0.8000
# Epoch 82/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.8998e-06 - accuracy: 1.0000 - val_loss: 1.3495 - val_accuracy: 0.8000
# Epoch 83/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.0454e-06 - accuracy: 1.0000 - val_loss: 1.3654 - val_accuracy: 0.8000
# Epoch 84/1000
# 3/3 [==============================] - 0s 101ms/step - loss: 4.8556e-06 - accuracy: 1.0000 - val_loss: 1.3808 - val_accuracy: 0.8000
# Epoch 85/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 4.1640e-06 - accuracy: 1.0000 - val_loss: 1.3955 - val_accuracy: 0.8000
# Epoch 86/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 3.6081e-06 - accuracy: 1.0000 - val_loss: 1.4105 - val_accuracy: 0.8000
# Epoch 87/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.7343e-05 - accuracy: 1.0000 - val_loss: 1.4239 - val_accuracy: 0.8000
# Epoch 88/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.0102e-05 - accuracy: 1.0000 - val_loss: 1.4339 - val_accuracy: 0.8000
# Epoch 89/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.3947e-06 - accuracy: 1.0000 - val_loss: 1.4473 - val_accuracy: 0.8000
# Epoch 90/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 9.8939e-06 - accuracy: 1.0000 - val_loss: 1.4580 - val_accuracy: 0.8000
# Epoch 91/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 6.4204e-06 - accuracy: 1.0000 - val_loss: 1.4735 - val_accuracy: 0.8000
# Epoch 92/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 7.2715e-06 - accuracy: 1.0000 - val_loss: 1.4859 - val_accuracy: 0.8000
# Epoch 93/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4533e-05 - accuracy: 1.0000 - val_loss: 1.4974 - val_accuracy: 0.8000
# Epoch 94/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.0509e-06 - accuracy: 1.0000 - val_loss: 1.5082 - val_accuracy: 0.8000
# Epoch 95/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.7366e-05 - accuracy: 1.0000 - val_loss: 1.5185 - val_accuracy: 0.8000
# Epoch 96/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.1208e-05 - accuracy: 1.0000 - val_loss: 1.5340 - val_accuracy: 0.8000
# Epoch 97/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.1277e-06 - accuracy: 1.0000 - val_loss: 1.5433 - val_accuracy: 0.8000
# Epoch 98/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.0319e-06 - accuracy: 1.0000 - val_loss: 1.5558 - val_accuracy: 0.8000
# Epoch 99/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.4410e-05 - accuracy: 1.0000 - val_loss: 1.5691 - val_accuracy: 0.8000
# Epoch 100/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 5.4696e-06 - accuracy: 1.0000 - val_loss: 1.5783 - val_accuracy: 0.8000
# Epoch 101/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.8694e-06 - accuracy: 1.0000 - val_loss: 1.5889 - val_accuracy: 0.8000
# Epoch 102/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.7596e-05 - accuracy: 1.0000 - val_loss: 1.6045 - val_accuracy: 0.8000
# Epoch 103/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.5936e-06 - accuracy: 1.0000 - val_loss: 1.6163 - val_accuracy: 0.8000
# Epoch 104/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1086e-04 - accuracy: 1.0000 - val_loss: 1.6251 - val_accuracy: 0.8000
# Epoch 105/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5379e-05 - accuracy: 1.0000 - val_loss: 1.6398 - val_accuracy: 0.8000
# Epoch 106/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 3.1174e-06 - accuracy: 1.0000 - val_loss: 1.6571 - val_accuracy: 0.8000
# Epoch 107/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 7.8191e-06 - accuracy: 1.0000 - val_loss: 1.6703 - val_accuracy: 0.8000
# Epoch 108/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.9497e-06 - accuracy: 1.0000 - val_loss: 1.6801 - val_accuracy: 0.8000
# Epoch 109/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2475e-05 - accuracy: 1.0000 - val_loss: 1.6905 - val_accuracy: 0.8000
# Epoch 110/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.1562e-06 - accuracy: 1.0000 - val_loss: 1.7031 - val_accuracy: 0.8000
# Epoch 111/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.5685e-06 - accuracy: 1.0000 - val_loss: 1.7105 - val_accuracy: 0.8000
# Epoch 112/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.2482e-05 - accuracy: 1.0000 - val_loss: 1.7216 - val_accuracy: 0.8000
# Epoch 113/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.7786e-06 - accuracy: 1.0000 - val_loss: 1.7339 - val_accuracy: 0.8000
# Epoch 114/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.9206e-06 - accuracy: 1.0000 - val_loss: 1.7410 - val_accuracy: 0.8000
# Epoch 115/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2182e-05 - accuracy: 1.0000 - val_loss: 1.7510 - val_accuracy: 0.8000
# Epoch 116/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.9115e-06 - accuracy: 1.0000 - val_loss: 1.7611 - val_accuracy: 0.8000
# Epoch 117/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.2913e-06 - accuracy: 1.0000 - val_loss: 1.7705 - val_accuracy: 0.8000
# Epoch 118/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.3371e-05 - accuracy: 1.0000 - val_loss: 1.7806 - val_accuracy: 0.8000
# Epoch 119/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8200e-06 - accuracy: 1.0000 - val_loss: 1.7874 - val_accuracy: 0.8000
# Epoch 120/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 5.5875e-06 - accuracy: 1.0000 - val_loss: 1.7946 - val_accuracy: 0.8000
# Epoch 121/1000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.2591e-05 - accuracy: 1.0000 - val_loss: 1.8067 - val_accuracy: 0.8000
# Epoch 122/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.9263e-06 - accuracy: 1.0000 - val_loss: 1.8157 - val_accuracy: 0.8000
# Epoch 123/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 3.0634e-06 - accuracy: 1.0000 - val_loss: 1.8247 - val_accuracy: 0.8000
# Epoch 124/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.5393e-05 - accuracy: 1.0000 - val_loss: 1.8344 - val_accuracy: 0.8000
# Epoch 125/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.0222e-06 - accuracy: 1.0000 - val_loss: 1.8383 - val_accuracy: 0.8000
# Epoch 126/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.8020e-05 - accuracy: 1.0000 - val_loss: 1.8448 - val_accuracy: 0.8000
# Epoch 127/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.1652e-06 - accuracy: 1.0000 - val_loss: 1.8503 - val_accuracy: 0.8000
# Epoch 128/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.8507e-06 - accuracy: 1.0000 - val_loss: 1.8535 - val_accuracy: 0.8000
# Epoch 129/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.8935e-06 - accuracy: 1.0000 - val_loss: 1.8570 - val_accuracy: 0.8000
# Epoch 130/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.3232e-06 - accuracy: 1.0000 - val_loss: 1.8629 - val_accuracy: 0.8000
# Epoch 131/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 9.0610e-06 - accuracy: 1.0000 - val_loss: 1.8643 - val_accuracy: 0.8000
# Epoch 132/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.5487e-06 - accuracy: 1.0000 - val_loss: 1.8672 - val_accuracy: 0.8000
# Epoch 133/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.5491e-06 - accuracy: 1.0000 - val_loss: 1.8689 - val_accuracy: 0.8000
# Epoch 134/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.7895e-06 - accuracy: 1.0000 - val_loss: 1.8704 - val_accuracy: 0.8000
# Epoch 135/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.7715e-06 - accuracy: 1.0000 - val_loss: 1.8732 - val_accuracy: 0.8000
# Epoch 136/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.9769e-05 - accuracy: 1.0000 - val_loss: 1.8767 - val_accuracy: 0.8000
# Epoch 137/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.0030e-06 - accuracy: 1.0000 - val_loss: 1.8796 - val_accuracy: 0.8000
# Epoch 138/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.1775e-05 - accuracy: 1.0000 - val_loss: 1.8838 - val_accuracy: 0.8000
# Epoch 139/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.5824e-06 - accuracy: 1.0000 - val_loss: 1.8876 - val_accuracy: 0.8000
# Epoch 140/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 7.4435e-06 - accuracy: 1.0000 - val_loss: 1.8919 - val_accuracy: 0.8000
# Epoch 141/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.2131e-06 - accuracy: 1.0000 - val_loss: 1.8917 - val_accuracy: 0.8000
# Epoch 142/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 3.3032e-06 - accuracy: 1.0000 - val_loss: 1.8952 - val_accuracy: 0.8000
# Epoch 143/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6467e-06 - accuracy: 1.0000 - val_loss: 1.8989 - val_accuracy: 0.8000
# Epoch 144/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.4355e-06 - accuracy: 1.0000 - val_loss: 1.9016 - val_accuracy: 0.8000
# Epoch 145/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.5802e-06 - accuracy: 1.0000 - val_loss: 1.9036 - val_accuracy: 0.8000
# Epoch 146/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.3578e-06 - accuracy: 1.0000 - val_loss: 1.9034 - val_accuracy: 0.8000
# Epoch 147/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 9.8844e-06 - accuracy: 1.0000 - val_loss: 1.9067 - val_accuracy: 0.8000
# Epoch 148/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 9.8653e-05 - accuracy: 1.0000 - val_loss: 1.9082 - val_accuracy: 0.8000
# Epoch 149/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.4673e-06 - accuracy: 1.0000 - val_loss: 1.9157 - val_accuracy: 0.8000
# Epoch 150/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 8.6672e-06 - accuracy: 1.0000 - val_loss: 1.9223 - val_accuracy: 0.8000
# Epoch 151/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 2.2961e-05 - accuracy: 1.0000 - val_loss: 1.9277 - val_accuracy: 0.8000
# Epoch 152/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1980e-05 - accuracy: 1.0000 - val_loss: 1.9317 - val_accuracy: 0.8000
# Epoch 153/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.2533e-06 - accuracy: 1.0000 - val_loss: 1.9375 - val_accuracy: 0.8000
# Epoch 154/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.1299e-06 - accuracy: 1.0000 - val_loss: 1.9410 - val_accuracy: 0.8000
# Epoch 155/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.5774e-06 - accuracy: 1.0000 - val_loss: 1.9469 - val_accuracy: 0.8000
# Epoch 156/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.7077e-06 - accuracy: 1.0000 - val_loss: 1.9499 - val_accuracy: 0.8000
# Epoch 157/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.7256e-05 - accuracy: 1.0000 - val_loss: 1.9524 - val_accuracy: 0.8000
# Epoch 158/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.3512e-06 - accuracy: 1.0000 - val_loss: 1.9528 - val_accuracy: 0.8000
# Epoch 159/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.7398e-06 - accuracy: 1.0000 - val_loss: 1.9562 - val_accuracy: 0.8000
# Epoch 160/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.3315e-06 - accuracy: 1.0000 - val_loss: 1.9561 - val_accuracy: 0.8000
# Epoch 161/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.3905e-06 - accuracy: 1.0000 - val_loss: 1.9572 - val_accuracy: 0.8000
# Epoch 162/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.3321e-06 - accuracy: 1.0000 - val_loss: 1.9582 - val_accuracy: 0.8000
# Epoch 163/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.0766e-06 - accuracy: 1.0000 - val_loss: 1.9602 - val_accuracy: 0.8000
# Epoch 164/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.5630e-06 - accuracy: 1.0000 - val_loss: 1.9626 - val_accuracy: 0.8000
# Epoch 165/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.2164e-06 - accuracy: 1.0000 - val_loss: 1.9606 - val_accuracy: 0.8000
# Epoch 166/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.2620e-05 - accuracy: 1.0000 - val_loss: 1.9626 - val_accuracy: 0.8000
# Epoch 167/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.8568e-06 - accuracy: 1.0000 - val_loss: 1.9615 - val_accuracy: 0.8000
# Epoch 168/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2739e-06 - accuracy: 1.0000 - val_loss: 1.9625 - val_accuracy: 0.8000
# Epoch 169/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.5885e-06 - accuracy: 1.0000 - val_loss: 1.9656 - val_accuracy: 0.8000
# Epoch 170/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.3661e-06 - accuracy: 1.0000 - val_loss: 1.9657 - val_accuracy: 0.8000
# Epoch 171/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.5879e-06 - accuracy: 1.0000 - val_loss: 1.9664 - val_accuracy: 0.8000
# Epoch 172/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.7806e-06 - accuracy: 1.0000 - val_loss: 1.9638 - val_accuracy: 0.8000
# Epoch 173/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.1374e-05 - accuracy: 1.0000 - val_loss: 1.9619 - val_accuracy: 0.8000
# Epoch 174/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.8907e-06 - accuracy: 1.0000 - val_loss: 1.9610 - val_accuracy: 0.8000
# Epoch 175/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 5.9063e-06 - accuracy: 1.0000 - val_loss: 1.9598 - val_accuracy: 0.8000
# Epoch 176/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 5.4406e-06 - accuracy: 1.0000 - val_loss: 1.9577 - val_accuracy: 0.8000
# Epoch 177/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.3462e-06 - accuracy: 1.0000 - val_loss: 1.9522 - val_accuracy: 0.8000
# Epoch 178/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.6802e-05 - accuracy: 1.0000 - val_loss: 1.9519 - val_accuracy: 0.8000
# Epoch 179/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.2309e-06 - accuracy: 1.0000 - val_loss: 1.9531 - val_accuracy: 0.8000
# Epoch 180/1000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.9462e-06 - accuracy: 1.0000 - val_loss: 1.9518 - val_accuracy: 0.8000
# Epoch 181/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.7327e-06 - accuracy: 1.0000 - val_loss: 1.9537 - val_accuracy: 0.8000
# Epoch 182/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.9947e-06 - accuracy: 1.0000 - val_loss: 1.9544 - val_accuracy: 0.8000
# Epoch 183/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.4951e-06 - accuracy: 1.0000 - val_loss: 1.9577 - val_accuracy: 0.8000
# Epoch 184/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.5713e-06 - accuracy: 1.0000 - val_loss: 1.9582 - val_accuracy: 0.8000
# Epoch 185/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.6519e-06 - accuracy: 1.0000 - val_loss: 1.9605 - val_accuracy: 0.8000
# Epoch 186/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.0149e-06 - accuracy: 1.0000 - val_loss: 1.9592 - val_accuracy: 0.8000
# Epoch 187/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.7420e-04 - accuracy: 1.0000 - val_loss: 1.9619 - val_accuracy: 0.8000
# Epoch 188/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.9503e-06 - accuracy: 1.0000 - val_loss: 1.9717 - val_accuracy: 0.8000
# Epoch 189/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.5982e-06 - accuracy: 1.0000 - val_loss: 1.9796 - val_accuracy: 0.8000
# Epoch 190/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.4194e-06 - accuracy: 1.0000 - val_loss: 1.9829 - val_accuracy: 0.8000
# Epoch 191/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.4153e-06 - accuracy: 1.0000 - val_loss: 1.9893 - val_accuracy: 0.8000
# Epoch 192/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 4.6145e-06 - accuracy: 1.0000 - val_loss: 1.9903 - val_accuracy: 0.8000
# Epoch 193/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.8004e-05 - accuracy: 1.0000 - val_loss: 1.9989 - val_accuracy: 0.8000
# Epoch 194/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.1815e-06 - accuracy: 1.0000 - val_loss: 2.0028 - val_accuracy: 0.8000
# Epoch 195/1000
# 3/3 [==============================] - 0s 103ms/step - loss: 2.3939e-06 - accuracy: 1.0000 - val_loss: 2.0016 - val_accuracy: 0.8000
# Epoch 196/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 5.9521e-06 - accuracy: 1.0000 - val_loss: 2.0024 - val_accuracy: 0.8000
# Epoch 197/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.3703e-06 - accuracy: 1.0000 - val_loss: 2.0076 - val_accuracy: 0.8000
# Epoch 198/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 6.4247e-06 - accuracy: 1.0000 - val_loss: 2.0089 - val_accuracy: 0.8000
# Epoch 199/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.2295e-06 - accuracy: 1.0000 - val_loss: 2.0128 - val_accuracy: 0.8000
# Epoch 200/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.3848e-06 - accuracy: 1.0000 - val_loss: 2.0173 - val_accuracy: 0.8000
# Epoch 201/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1533e-06 - accuracy: 1.0000 - val_loss: 2.0184 - val_accuracy: 0.8000
# Epoch 202/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.5353e-06 - accuracy: 1.0000 - val_loss: 2.0149 - val_accuracy: 0.8000
# Epoch 203/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 8.7019e-06 - accuracy: 1.0000 - val_loss: 2.0152 - val_accuracy: 0.8000
# Epoch 204/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.3220e-06 - accuracy: 1.0000 - val_loss: 2.0148 - val_accuracy: 0.8000
# Epoch 205/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.1066e-05 - accuracy: 1.0000 - val_loss: 2.0090 - val_accuracy: 0.8000
# Epoch 206/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.5865e-06 - accuracy: 1.0000 - val_loss: 2.0057 - val_accuracy: 0.8000
# Epoch 207/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.1339e-06 - accuracy: 1.0000 - val_loss: 2.0047 - val_accuracy: 0.8000
# Epoch 208/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 2.9248e-06 - accuracy: 1.0000 - val_loss: 2.0080 - val_accuracy: 0.8000
# Epoch 209/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.4929e-06 - accuracy: 1.0000 - val_loss: 2.0088 - val_accuracy: 0.8000
# Epoch 210/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.8658e-06 - accuracy: 1.0000 - val_loss: 2.0096 - val_accuracy: 0.8000
# Epoch 211/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.4929e-06 - accuracy: 1.0000 - val_loss: 2.0096 - val_accuracy: 0.8000
# Epoch 212/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 8.8461e-06 - accuracy: 1.0000 - val_loss: 2.0056 - val_accuracy: 0.8000
# Epoch 213/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 9.0929e-06 - accuracy: 1.0000 - val_loss: 2.0015 - val_accuracy: 0.8000
# Epoch 214/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.4992e-06 - accuracy: 1.0000 - val_loss: 1.9938 - val_accuracy: 0.8000
# Epoch 215/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 4.9041e-06 - accuracy: 1.0000 - val_loss: 1.9862 - val_accuracy: 0.8000
# Epoch 216/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.2844e-06 - accuracy: 1.0000 - val_loss: 1.9834 - val_accuracy: 0.8000
# Epoch 217/1000
# 3/3 [==============================] - 0s 105ms/step - loss: 1.2822e-06 - accuracy: 1.0000 - val_loss: 1.9774 - val_accuracy: 0.8000
# Epoch 218/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 8.9640e-06 - accuracy: 1.0000 - val_loss: 1.9737 - val_accuracy: 0.8000
# Epoch 219/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.0487e-06 - accuracy: 1.0000 - val_loss: 1.9667 - val_accuracy: 0.8000
# Epoch 220/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 6.6423e-06 - accuracy: 1.0000 - val_loss: 1.9569 - val_accuracy: 0.8000
# Epoch 221/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.2018e-06 - accuracy: 1.0000 - val_loss: 1.9444 - val_accuracy: 0.8000
# Epoch 222/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 7.6306e-06 - accuracy: 1.0000 - val_loss: 1.9373 - val_accuracy: 0.8000
# Epoch 223/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1463e-06 - accuracy: 1.0000 - val_loss: 1.9275 - val_accuracy: 0.8000
# Epoch 224/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.1402e-06 - accuracy: 1.0000 - val_loss: 1.9192 - val_accuracy: 0.8000
# Epoch 225/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.9004e-06 - accuracy: 1.0000 - val_loss: 1.9098 - val_accuracy: 0.8000
# Epoch 226/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.9962e-06 - accuracy: 1.0000 - val_loss: 1.9030 - val_accuracy: 0.8000
# Epoch 227/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0008e-06 - accuracy: 1.0000 - val_loss: 1.8928 - val_accuracy: 0.8000
# Epoch 228/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.9018e-06 - accuracy: 1.0000 - val_loss: 1.8827 - val_accuracy: 0.8000
# Epoch 229/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.3543e-06 - accuracy: 1.0000 - val_loss: 1.8774 - val_accuracy: 0.8000
# Epoch 230/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 5.9853e-06 - accuracy: 1.0000 - val_loss: 1.8725 - val_accuracy: 0.8000
# Epoch 231/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.4285e-06 - accuracy: 1.0000 - val_loss: 1.8669 - val_accuracy: 0.8000
# Epoch 232/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.4812e-06 - accuracy: 1.0000 - val_loss: 1.8602 - val_accuracy: 0.8000
# Epoch 233/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 6.3582e-06 - accuracy: 1.0000 - val_loss: 1.8523 - val_accuracy: 0.8000
# Epoch 234/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.1133e-06 - accuracy: 1.0000 - val_loss: 1.8477 - val_accuracy: 0.8000
# Epoch 235/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.9935e-06 - accuracy: 1.0000 - val_loss: 1.8398 - val_accuracy: 0.8000
# Epoch 236/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.3587e-04 - accuracy: 1.0000 - val_loss: 1.8350 - val_accuracy: 0.8000
# Epoch 237/1000
# 3/3 [==============================] - 0s 105ms/step - loss: 8.4555e-07 - accuracy: 1.0000 - val_loss: 1.8192 - val_accuracy: 0.8000
# Epoch 238/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 6.8558e-06 - accuracy: 1.0000 - val_loss: 1.8082 - val_accuracy: 0.8000
# Epoch 239/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.3412e-06 - accuracy: 1.0000 - val_loss: 1.7982 - val_accuracy: 0.8000
# Epoch 240/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8962e-06 - accuracy: 1.0000 - val_loss: 1.7912 - val_accuracy: 0.8000
# Epoch 241/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 2.9677e-06 - accuracy: 1.0000 - val_loss: 1.7824 - val_accuracy: 0.8000
# Epoch 242/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.0241e-05 - accuracy: 1.0000 - val_loss: 1.7716 - val_accuracy: 0.8000
# Epoch 243/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 5.3172e-06 - accuracy: 1.0000 - val_loss: 1.7571 - val_accuracy: 0.8000
# Epoch 244/1000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.4333e-06 - accuracy: 1.0000 - val_loss: 1.7443 - val_accuracy: 0.8000
# Epoch 245/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.6295e-06 - accuracy: 1.0000 - val_loss: 1.7332 - val_accuracy: 0.8000
# Epoch 246/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 5.0760e-06 - accuracy: 1.0000 - val_loss: 1.7210 - val_accuracy: 0.8000
# Epoch 247/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.3178e-06 - accuracy: 1.0000 - val_loss: 1.7137 - val_accuracy: 0.8000
# Epoch 248/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4832e-06 - accuracy: 1.0000 - val_loss: 1.7049 - val_accuracy: 0.8000
# Epoch 249/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.9364e-06 - accuracy: 1.0000 - val_loss: 1.6949 - val_accuracy: 0.8000
# Epoch 250/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.1574e-06 - accuracy: 1.0000 - val_loss: 1.6859 - val_accuracy: 0.8000
# Epoch 251/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.3155e-06 - accuracy: 1.0000 - val_loss: 1.6790 - val_accuracy: 0.8000
# Epoch 252/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1339e-06 - accuracy: 1.0000 - val_loss: 1.6703 - val_accuracy: 0.8000
# Epoch 253/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 6.0893e-06 - accuracy: 1.0000 - val_loss: 1.6622 - val_accuracy: 0.8000
# Epoch 254/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.2893e-06 - accuracy: 1.0000 - val_loss: 1.6534 - val_accuracy: 0.8000
# Epoch 255/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.1186e-06 - accuracy: 1.0000 - val_loss: 1.6457 - val_accuracy: 0.8000
# Epoch 256/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.7897e-06 - accuracy: 1.0000 - val_loss: 1.6403 - val_accuracy: 0.8000
# Epoch 257/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 9.9248e-07 - accuracy: 1.0000 - val_loss: 1.6323 - val_accuracy: 0.8000
# Epoch 258/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.5497e-06 - accuracy: 1.0000 - val_loss: 1.6245 - val_accuracy: 0.8000
# Epoch 259/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.3279e-06 - accuracy: 1.0000 - val_loss: 1.6178 - val_accuracy: 0.8000
# Epoch 260/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 9.3951e-06 - accuracy: 1.0000 - val_loss: 1.6073 - val_accuracy: 0.8000
# Epoch 261/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.3806e-06 - accuracy: 1.0000 - val_loss: 1.5977 - val_accuracy: 0.8000
# Epoch 262/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.4576e-06 - accuracy: 1.0000 - val_loss: 1.5880 - val_accuracy: 0.8000
# Epoch 263/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.2517e-06 - accuracy: 1.0000 - val_loss: 1.5775 - val_accuracy: 0.8000
# Epoch 264/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.2026e-06 - accuracy: 1.0000 - val_loss: 1.5644 - val_accuracy: 0.8000
# Epoch 265/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1921e-06 - accuracy: 1.0000 - val_loss: 1.5531 - val_accuracy: 0.8000
# Epoch 266/1000
# 3/3 [==============================] - 0s 103ms/step - loss: 2.3384e-06 - accuracy: 1.0000 - val_loss: 1.5393 - val_accuracy: 0.8000
# Epoch 267/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.6739e-06 - accuracy: 1.0000 - val_loss: 1.5246 - val_accuracy: 0.8000
# Epoch 268/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 4.8127e-06 - accuracy: 1.0000 - val_loss: 1.5080 - val_accuracy: 0.8000
# Epoch 269/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1463e-06 - accuracy: 1.0000 - val_loss: 1.4886 - val_accuracy: 0.8000
# Epoch 270/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.6398e-06 - accuracy: 1.0000 - val_loss: 1.4712 - val_accuracy: 0.8000
# Epoch 271/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.3370e-06 - accuracy: 1.0000 - val_loss: 1.4591 - val_accuracy: 0.8000
# Epoch 272/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 8.7213e-06 - accuracy: 1.0000 - val_loss: 1.4466 - val_accuracy: 0.8000
# Epoch 273/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.1804e-06 - accuracy: 1.0000 - val_loss: 1.4349 - val_accuracy: 0.8000
# Epoch 274/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.4782e-06 - accuracy: 1.0000 - val_loss: 1.4189 - val_accuracy: 0.8000
# Epoch 275/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.4826e-06 - accuracy: 1.0000 - val_loss: 1.4039 - val_accuracy: 0.8000
# Epoch 276/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0590e-06 - accuracy: 1.0000 - val_loss: 1.3891 - val_accuracy: 0.8000
# Epoch 277/1000
# 3/3 [==============================] - 0s 101ms/step - loss: 2.6254e-06 - accuracy: 1.0000 - val_loss: 1.3700 - val_accuracy: 0.8000
# Epoch 278/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.7103e-06 - accuracy: 1.0000 - val_loss: 1.3511 - val_accuracy: 0.8000
# Epoch 279/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 6.3398e-05 - accuracy: 1.0000 - val_loss: 1.3334 - val_accuracy: 0.8000
# Epoch 280/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.6393e-05 - accuracy: 1.0000 - val_loss: 1.3096 - val_accuracy: 0.8000
# Epoch 281/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.1380e-06 - accuracy: 1.0000 - val_loss: 1.2850 - val_accuracy: 0.8000
# Epoch 282/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.8865e-06 - accuracy: 1.0000 - val_loss: 1.2581 - val_accuracy: 0.8000
# Epoch 283/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.0141e-06 - accuracy: 1.0000 - val_loss: 1.2327 - val_accuracy: 0.8000
# Epoch 284/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0386e-05 - accuracy: 1.0000 - val_loss: 1.2005 - val_accuracy: 0.8000
# Epoch 285/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.7842e-06 - accuracy: 1.0000 - val_loss: 1.1724 - val_accuracy: 0.8000
# Epoch 286/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 3.2824e-06 - accuracy: 1.0000 - val_loss: 1.1445 - val_accuracy: 0.8000
# Epoch 287/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.7964e-06 - accuracy: 1.0000 - val_loss: 1.1179 - val_accuracy: 0.8000
# Epoch 288/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.7974e-06 - accuracy: 1.0000 - val_loss: 1.0893 - val_accuracy: 0.8000
# Epoch 289/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 7.7192e-06 - accuracy: 1.0000 - val_loss: 1.0610 - val_accuracy: 0.8000
# Epoch 290/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0770e-06 - accuracy: 1.0000 - val_loss: 1.0352 - val_accuracy: 0.8000
# Epoch 291/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.7862e-06 - accuracy: 1.0000 - val_loss: 1.0130 - val_accuracy: 0.8000
# Epoch 292/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.6836e-06 - accuracy: 1.0000 - val_loss: 1.0000 - val_accuracy: 0.8000
# Epoch 293/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.0848e-06 - accuracy: 1.0000 - val_loss: 0.9864 - val_accuracy: 0.8000
# Epoch 294/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.3877e-06 - accuracy: 1.0000 - val_loss: 0.9758 - val_accuracy: 0.8000
# Epoch 295/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 5.6914e-06 - accuracy: 1.0000 - val_loss: 0.9682 - val_accuracy: 0.8000
# Epoch 296/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.7772e-06 - accuracy: 1.0000 - val_loss: 0.9527 - val_accuracy: 0.8000
# Epoch 297/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.4749e-06 - accuracy: 1.0000 - val_loss: 0.9405 - val_accuracy: 0.8000
# Epoch 298/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 7.0692e-06 - accuracy: 1.0000 - val_loss: 0.9278 - val_accuracy: 0.8000
# Epoch 299/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.1683e-05 - accuracy: 1.0000 - val_loss: 0.9138 - val_accuracy: 0.8000
# Epoch 300/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.7659e-06 - accuracy: 1.0000 - val_loss: 0.8947 - val_accuracy: 0.8000
# Epoch 301/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 4.3622e-06 - accuracy: 1.0000 - val_loss: 0.8670 - val_accuracy: 0.8000
# Epoch 302/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 9.6338e-07 - accuracy: 1.0000 - val_loss: 0.8347 - val_accuracy: 0.8000
# Epoch 303/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 6.8183e-06 - accuracy: 1.0000 - val_loss: 0.7983 - val_accuracy: 0.8000
# Epoch 304/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 3.4640e-06 - accuracy: 1.0000 - val_loss: 0.7636 - val_accuracy: 0.8000
# Epoch 305/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.5899e-06 - accuracy: 1.0000 - val_loss: 0.7263 - val_accuracy: 0.8000
# Epoch 306/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.5691e-06 - accuracy: 1.0000 - val_loss: 0.6914 - val_accuracy: 0.8000
# Epoch 307/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1186e-06 - accuracy: 1.0000 - val_loss: 0.6556 - val_accuracy: 0.8000
# Epoch 308/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 9.3855e-06 - accuracy: 1.0000 - val_loss: 0.6261 - val_accuracy: 0.8000
# Epoch 309/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.0637e-06 - accuracy: 1.0000 - val_loss: 0.6015 - val_accuracy: 0.8000
# Epoch 310/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 9.2734e-07 - accuracy: 1.0000 - val_loss: 0.5778 - val_accuracy: 0.8000
# Epoch 311/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 4.9941e-06 - accuracy: 1.0000 - val_loss: 0.5547 - val_accuracy: 0.8000
# Epoch 312/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.0861e-06 - accuracy: 1.0000 - val_loss: 0.5357 - val_accuracy: 0.9000
# Epoch 313/1000
# 3/3 [==============================] - 0s 107ms/step - loss: 1.6717e-06 - accuracy: 1.0000 - val_loss: 0.5206 - val_accuracy: 0.9000
# Epoch 314/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 4.1335e-06 - accuracy: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.9000
# Epoch 315/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 4.8531e-05 - accuracy: 1.0000 - val_loss: 0.4895 - val_accuracy: 0.9000
# Epoch 316/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.0152e-06 - accuracy: 1.0000 - val_loss: 0.4714 - val_accuracy: 0.9000
# Epoch 317/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.1061e-06 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.9000
# Epoch 318/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.0543e-06 - accuracy: 1.0000 - val_loss: 0.4370 - val_accuracy: 0.9000
# Epoch 319/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.3279e-06 - accuracy: 1.0000 - val_loss: 0.4208 - val_accuracy: 0.9000
# Epoch 320/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0343 - accuracy: 0.9884 - val_loss: 0.7484 - val_accuracy: 0.8000
# Epoch 321/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0726 - accuracy: 0.9767 - val_loss: 1.1396 - val_accuracy: 0.8000
# Epoch 322/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.3261 - val_accuracy: 0.8000
# Epoch 323/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.8398 - val_accuracy: 0.8000
# Epoch 324/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.2845 - val_accuracy: 0.8000
# Epoch 325/1000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.6993 - val_accuracy: 0.8000
# Epoch 326/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.9395 - val_accuracy: 0.8000
# Epoch 327/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.0511 - val_accuracy: 0.8000
# Epoch 328/1000
# ...
# Epoch 900/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 9.1069e-07 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 1.0000
# Epoch 901/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 8.5942e-08 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 902/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 9.0100e-08 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 903/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 4.8085e-06 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 1.0000
# Epoch 904/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.7822e-07 - accuracy: 1.0000 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 905/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 4.4495e-07 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 1.0000
# Epoch 906/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.2594e-07 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 1.0000
# Epoch 907/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.8693e-07 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 1.0000
# Epoch 908/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.1460e-06 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 909/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.0301e-06 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000
# Epoch 910/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.5802e-07 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 911/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 7.9981e-07 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 1.0000
# Epoch 912/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 6.6811e-06 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 913/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.2844e-06 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000
# Epoch 914/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.6337e-07 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000
# Epoch 915/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.3860e-05 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 916/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.8644e-06 - accuracy: 1.0000 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 917/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.6412e-06 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 1.0000
# Epoch 918/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6357e-07 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 919/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 8.7328e-08 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 920/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0673e-07 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 1.0000
# Epoch 921/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.0808e-06 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 922/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.7030e-07 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 923/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 9.2872e-08 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 924/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.2713e-07 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 925/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.2456e-07 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 926/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.1485e-07 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 927/1000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.2872e-07 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 928/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0673e-07 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 929/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.8533e-06 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 930/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.7307e-07 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 931/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 5.7803e-07 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 932/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.6772e-07 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 933/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 6.6258e-07 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 934/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.5367e-07 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 935/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.4433e-05 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 936/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.5505e-07 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 937/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0285e-06 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 938/1000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.9248e-07 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 939/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.4792e-07 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 940/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 8.7328e-08 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 941/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 4.5561e-06 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 942/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.2491e-06 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 943/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.2178e-07 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 944/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 9.1763e-07 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 945/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.6079e-07 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 946/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 8.5942e-08 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 947/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.0515e-07 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 948/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.4931e-07 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 1.0000
# Epoch 949/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0507e-06 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 950/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.2733e-07 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 1.0000
# Epoch 951/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.0376e-07 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 952/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.6343e-06 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 953/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6384e-06 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 954/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0119e-07 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 955/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1089e-07 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 956/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 8.8475e-06 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 957/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 5.8218e-08 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 958/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.9783e-07 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 959/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 4.0198e-07 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 960/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.2600e-06 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 961/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 9.8417e-08 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 962/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.2753e-07 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 963/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.4141e-06 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 964/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.1763e-07 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 965/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1089e-07 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 966/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.6357e-07 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 967/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 9.4258e-08 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 968/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.5248e-07 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 969/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.3113e-06 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 970/1000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.3875e-06 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 971/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.8097e-06 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 972/1000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.0099e-06 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 973/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3862e-07 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 974/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.4416e-07 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 975/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.5525e-07 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 976/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 6.6119e-07 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 977/1000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2656e-06 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 978/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.6179e-07 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 979/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.4674e-07 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 980/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 4.5769e-06 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 981/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.6114e-06 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 982/1000
# 3/3 [==============================] - 0s 84ms/step - loss: 8.8020e-07 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 983/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.4832e-07 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 1.0000
# Epoch 984/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 6.8753e-07 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 985/1000
# 3/3 [==============================] - 0s 99ms/step - loss: 8.0535e-07 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 986/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1366e-06 - accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 987/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.7350e-06 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 988/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.2317e-07 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 1.0000
# Epoch 989/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.7149e-07 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 990/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1007e-05 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 991/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.0931e-07 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 992/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 8.4971e-07 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 993/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.8852e-07 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 1.0000
# Epoch 994/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.1030e-07 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 995/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.3584e-07 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 996/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.3168e-07 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 1.0000
# Epoch 997/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.4596e-06 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 998/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 9.0100e-08 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 999/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.4970e-07 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 1000/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.1485e-07 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8369 - accuracy: 0.9167
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000246B7345160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# No.1 test score = 91.667 %
# No.2 test score = 95.833 %
# No.3 test score = 95.833 %
# No.4 test score = 100.000 %
# No.5 test score = 91.667 %
# average score = 95.000 %
# Total processing time: 1401.08 seconds
