# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir output_VGG16/logs
# Out:
#       <iframe id="tensorboard-frame-31177eba10644881" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-31177eba10644881");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import os
import glob
import numpy as np
import random as rn
import matplotlib.pyplot as plt
import shutil
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Activation
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import time
from tensorflow.keras.callbacks import TensorBoard
import datetime

# %%
# Record the start time of the process
start_time = time.time()

# Parameter settings
class_num = 2  # Number of classes (male: 0, female: 1)
epochs = 400  # Number of training epochs
batch_size = 32  # Batch size
COLOR_CHANNEL = 3  # 3 for RGB images, 1 for grayscale
INPUT_IMAGE_SIZE = 224  # Input image size

# %%
# Folder paths
male_folder = ''
female_folder = ''
id_image_folder = ''
output_folder = ''

# Create folders to save images with IDs
os.makedirs(id_image_folder, exist_ok=True)
male_id_folder = os.path.join(id_image_folder, 'male')
female_id_folder = os.path.join(id_image_folder, 'female')
os.makedirs(male_id_folder, exist_ok=True)
os.makedirs(female_id_folder, exist_ok=True)

# Load images and assign labels
image_data = []
labels = []
image_paths = []  # List to keep IDs of each image

# Load images from the male_hara folder and assign male labels (0)
male_images = glob.glob(f"{male_folder}/*.jpg")
for idx, file in enumerate(male_images):
    img = load_img(file, color_mode="rgb", target_size=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE))
    img_array = img_to_array(img)
    filename = f"male_{idx+1}.jpg"
    img.save(os.path.join(male_id_folder, filename))
    image_data.append(img_array)
    labels.append(0)  # Use 0 as the label for males
    image_paths.append(filename)  # Add a number to male image IDs

# Load images from the female_hara folder and assign female labels (1)
female_images = glob.glob(f"{female_folder}/*.jpg")
for idx, file in enumerate(female_images):
    img = load_img(file, color_mode="rgb", target_size=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE))
    img_array = img_to_array(img)
    filename = f"female_{idx+1}.jpg"
    img.save(os.path.join(female_id_folder, filename))
    image_data.append(img_array)
    labels.append(1)  # Use 1 as the label for females
    image_paths.append(filename)  # Add a number to female image IDs

# Convert to NumPy arrays
image_data = np.array(image_data)
labels = np.array(labels)

# Normalize images to the range [0, 1]
image_data = image_data.astype('float32')
image_data /= 255.0

# Convert labels to one-hot encoding
labels = to_categorical(labels, class_num)

# Output the number of loaded images
print(f"Male images: {len(male_images)}")
print(f"Female images: {len(female_images)}")
print(f"Total images: {len(male_images) + len(female_images)}")
# Out:
# Male images: 60
# Female images: 60
# Total images: 120

# %%
# Data splitting settings
sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

# Arrays to store results
result = []
f1_scores = []

# Log directory for TensorBoard
log_dir = os.path.join(output_folder, "logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
os.makedirs(log_dir, exist_ok=True)

# Process for each fold
for fold, (train_index, test_index) in enumerate(sss.split(image_data, np.argmax(labels, axis=1))):
    # Create folder for the fold
    fold_folder = os.path.join(output_folder, f'fold_{fold+1}')
    os.makedirs(fold_folder, exist_ok=True)

    # TensorBoard settings
    tensorboard_callback = TensorBoard(log_dir=os.path.join(log_dir, f"fold_{fold+1}"), histogram_freq=1)
    
    # Create folders to save training and testing images
    train_folder = os.path.join(fold_folder, 'train_images')
    test_folder = os.path.join(fold_folder, 'test_images')
    os.makedirs(train_folder, exist_ok=True)
    os.makedirs(test_folder, exist_ok=True)

    # Copy and save training and testing images
    for idx in train_index:
        src_path = os.path.join(id_image_folder, 'male' if labels[idx][0] == 1 else 'female', image_paths[idx])
        shutil.copy(src_path, os.path.join(train_folder, image_paths[idx]))
    for idx in test_index:
        src_path = os.path.join(id_image_folder, 'male' if labels[idx][0] == 1 else 'female', image_paths[idx])
        shutil.copy(src_path, os.path.join(test_folder, image_paths[idx]))

    # Build the model
    vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(INPUT_IMAGE_SIZE, INPUT_IMAGE_SIZE, COLOR_CHANNEL))
    model = Sequential(vgg16.layers)
    
    for layer in model.layers[:14]:
        layer.trainable = False

    # Add custom layers
    model.add(Flatten())
    model.add(Dense(256, activation="relu"))  # Fully connected layer 2
    model.add(Dropout(0.5))
    model.add(Dense(class_num, activation="softmax"))  # Output layer

    # Compile the model
    model.compile(optimizer=SGD(learning_rate=0.01), 
                  loss='categorical_crossentropy', metrics=['accuracy'])

    model.summary()

    # Training
    history = model.fit(image_data[train_index], labels[train_index],
                        batch_size=batch_size, epochs=epochs, verbose=1, validation_split=0.1, callbacks=[tensorboard_callback])

    # Evaluate on test data
    test_score = model.evaluate(image_data[test_index], labels[test_index], verbose=1)
    result.append(test_score[1] * 100)

    # Calculate F1 score
    y_pred = model.predict(image_data[test_index])
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(labels[test_index], axis=1)
    f1 = f1_score(y_test_classes, y_pred_classes, average='weighted')  # Calculate F1 score with weighted average
    f1_scores.append(f1)
    print(f"Fold {fold+1} - Accuracy: {test_score[1] * 100:.3f}%, F1 Score: {f1:.4f}")

    # Save the model
    model.save(os.path.join(fold_folder, f'model_fold_{fold+1}.h5'))

    # Save training history
    plt.figure()
    plt.plot(range(epochs), history.history['loss'], label='Train loss')
    plt.plot(range(epochs), history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig(os.path.join(fold_folder, 'loss_plot.png'))
    plt.close()

    plt.figure()
    plt.plot(range(epochs), history.history['accuracy'], label='Train Accuracy')
    plt.plot(range(epochs), history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig(os.path.join(fold_folder, 'accuracy_plot.png'))
    plt.close()

    # Save confusion matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['male', 'female'])
    disp.plot(cmap='Greens', values_format='d')
    plt.savefig(os.path.join(fold_folder, 'confusion_matrix.png'))
    plt.close()

# Aggregate and display/save overall results
summary_path = os.path.join(output_folder, 'result_summary.txt')
with open(summary_path, 'w') as f:
    # Output and save results for each fold
    for i, (score, f1) in enumerate(zip(result, f1_scores), start=1):
        result_text = f'No.{i} test score = {score:.3f} %, F1 Score = {f1:.4f}'
        f.write(result_text + '\n')
        print(result_text)

    # Calculate and output/save average scores
    average_score = sum(result) / len(result)
    average_f1 = sum(f1_scores) / len(f1_scores)
    average_text = f'average score = {average_score:.3f} %, average F1 Score = {average_f1:.4f}'
    f.write(average_text + '\n')
    print(average_text)

# Record the end time of the process and calculate the elapsed time
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Total processing time: {elapsed_time:.2f} seconds")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params:
ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9000
# Epoch 44/400
# 3/3 [==============================] - 1s 582ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9000
# Epoch 45/400
# 3/3 [==============================] - 1s 573ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9000
# Epoch 46/400
# 3/3 [==============================] - 1s 567ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9000
# Epoch 47/400
# 3/3 [==============================] - 1s 547ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9000
# Epoch 48/400
# 3/3 [==============================] - 1s 575ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9000
# Epoch 49/400
# 3/3 [==============================] - 1s 582ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9000
# Epoch 50/400
# 3/3 [==============================] - 1s 558ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9000
# Epoch 51/400
# 3/3 [==============================] - 1s 565ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9000
# Epoch 52/400
# 3/3 [==============================] - 1s 564ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9000
# Epoch 53/400
# 3/3 [==============================] - 1s 550ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9000
# Epoch 54/400
# 3/3 [==============================] - 1s 575ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9000
# Epoch 55/400
# 3/3 [==============================] - 1s 558ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9000
# Epoch 56/400
# 3/3 [==============================] - 1s 565ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9000
# Epoch 57/400
# 3/3 [==============================] - 1s 582ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1811 - val_accuracy: 0.9000
# Epoch 58/400
# 3/3 [==============================] - 1s 552ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9000
# Epoch 59/400
# 3/3 [==============================] - 1s 570ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9000
# Epoch 60/400
# 3/3 [==============================] - 1s 563ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9000
# Epoch 61/400
# 3/3 [==============================] - 1s 570ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9000
# Epoch 62/400
# 3/3 [==============================] - 1s 580ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9000
# Epoch 63/400
# 3/3 [==============================] - 1s 550ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9000
# Epoch 64/400
# 3/3 [==============================] - 1s 551ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9000
# Epoch 65/400
# 3/3 [==============================] - 1s 577ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9000
# Epoch 66/400
# 3/3 [==============================] - 1s 576ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9000
# Epoch 67/400
# 3/3 [==============================] - 1s 566ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9000
# Epoch 68/400
# 3/3 [==============================] - 1s 568ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9000
# Epoch 69/400
# 3/3 [==============================] - 1s 565ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9000
# Epoch 70/400
# 3/3 [==============================] - 1s 617ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9000
# Epoch 71/400
# 3/3 [==============================] - 1s 581ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 0.9000
# Epoch 72/400
# 3/3 [==============================] - 1s 561ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9000
# Epoch 73/400
# 3/3 [==============================] - 1s 575ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9000
# Epoch 74/400
# 3/3 [==============================] - 1s 554ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9000
# Epoch 75/400
# 3/3 [==============================] - 1s 570ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9000
# Epoch 76/400
# 3/3 [==============================] - 1s 571ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9000
# Epoch 77/400
# 3/3 [==============================] - 1s 607ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1023 - val_accuracy: 0.9000
# Epoch 78/400
# 3/3 [==============================] - 1s 569ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9000
# Epoch 79/400
# 3/3 [==============================] - 1s 562ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9000
# Epoch 80/400
# 3/3 [==============================] - 1s 603ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9000
# Epoch 81/400
# 3/3 [==============================] - 1s 567ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9000
# Epoch 82/400
# 3/3 [==============================] - 1s 586ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9000
# Epoch 83/400
# 3/3 [==============================] - 1s 585ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9000
# Epoch 84/400
# 3/3 [==============================] - 1s 573ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 0.9000
# Epoch 85/400
# 3/3 [==============================] - 1s 584ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9000
# Epoch 86/400
# 3/3 [==============================] - 1s 583ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9000
# Epoch 87/400
# 3/3 [==============================] - 1s 588ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9000
# Epoch 88/400
# 3/3 [==============================] - 1s 591ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9000
# Epoch 89/400
# 3/3 [==============================] - 1s 565ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9000
# Epoch 90/400
# 3/3 [==============================] - 1s 579ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 91/400
# 3/3 [==============================] - 1s 566ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9000
# Epoch 92/400
# 3/3 [==============================] - 1s 584ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 0.9000
# Epoch 93/400
# 3/3 [==============================] - 1s 567ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9000
# Epoch 94/400
# 3/3 [==============================] - 1s 562ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9000
# Epoch 95/400
# 3/3 [==============================] - 1s 586ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9000
# Epoch 96/400
# 3/3 [==============================] - 1s 568ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9000
# Epoch 97/400
# 3/3 [==============================] - 1s 573ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9000
# Epoch 98/400
# 3/3 [==============================] - 1s 576ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9000
# Epoch 99/400
# 3/3 [==============================] - 1s 564ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9000
# Epoch 100/400
# 3/3 [==============================] - 1s 559ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9000
# Epoch 101/400
# 3/3 [==============================] - 1s 590ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9000
# Epoch 102/400
# 3/3 [==============================] - 1s 573ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 103/400
# 3/3 [==============================] - 1s 568ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9000
# Epoch 104/400
# 3/3 [==============================] - 1s 569ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9000
# Epoch 105/400
# 3/3 [==============================] - 1s 563ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9000
# Epoch 106/400
# 3/3 [==============================] - 1s 581ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1106 - val_accuracy: 0.9000
# Epoch 107/400
# 3/3 [==============================] - 1s 580ms/step - loss: 7.5471e-04 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9000
# Epoch 108/400
# 3/3 [==============================] - 1s 613ms/step - loss: 8.5291e-04 - accuracy: 1.0000 - val_loss: 0.1120 - val_accuracy: 0.9000
# Epoch 109/400
# 3/3 [==============================] - 1s 560ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9000
# Epoch 110/400
# 3/3 [==============================] - 1s 559ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9000
# Epoch 111/400
# 3/3 [==============================] - 1s 573ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9000
# Epoch 112/400
# 3/3 [==============================] - 1s 588ms/step - loss: 9.8198e-04 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9000
# Epoch 113/400
# 3/3 [==============================] - 1s 562ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 0.9000
# Epoch 114/400
# 3/3 [==============================] - 1s 568ms/step - loss: 9.7944e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9000
# Epoch 115/400
# 3/3 [==============================] - 1s 542ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9000
# Epoch 116/400
# 3/3 [==============================] - 1s 589ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9000
# Epoch 117/400
# 3/3 [==============================] - 1s 591ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9000
# Epoch 118/400
# 3/3 [==============================] - 1s 584ms/step - loss: 8.4145e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9000
# Epoch 119/400
# 3/3 [==============================] - 1s 580ms/step - loss: 6.7292e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.
- accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 1.0000
# Epoch 379/400
# 3/3 [==============================] - 1s 571ms/step - loss: 1.7922e-04 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 1.0000
# Epoch 380/400
# 3/3 [==============================] - 1s 564ms/step - loss: 1.2503e-04 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 381/400
# 3/3 [==============================] - 1s 573ms/step - loss: 3.2088e-04 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 382/400
# 3/3 [==============================] - 1s 615ms/step - loss: 3.9958e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 1.0000
# Epoch 383/400
# 3/3 [==============================] - 1s 550ms/step - loss: 1.9711e-04 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 1.0000
# Epoch 384/400
# 3/3 [==============================] - 1s 563ms/step - loss: 1.9057e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 1.0000
# Epoch 385/400
# 3/3 [==============================] - 1s 567ms/step - loss: 1.3887e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 1.0000
# Epoch 386/400
# 3/3 [==============================] - 1s 571ms/step - loss: 9.9531e-05 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 1.0000
# Epoch 387/400
# 3/3 [==============================] - 1s 556ms/step - loss: 1.0706e-04 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 1.0000
# Epoch 388/400
# 3/3 [==============================] - 1s 562ms/step - loss: 1.1895e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 1.0000
# Epoch 389/400
# 3/3 [==============================] - 1s 549ms/step - loss: 1.6924e-04 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 1.0000
# Epoch 390/400
# 3/3 [==============================] - 1s 581ms/step - loss: 1.6397e-04 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 391/400
# 3/3 [==============================] - 1s 568ms/step - loss: 6.9598e-05 - accuracy: 1.0000 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 392/400
# 3/3 [==============================] - 1s 572ms/step - loss: 3.0508e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 393/400
# 3/3 [==============================] - 1s 578ms/step - loss: 2.8060e-04 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 1.0000
# Epoch 394/400
# 3/3 [==============================] - 1s 555ms/step - loss: 2.1959e-04 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 1.0000
# Epoch 395/400
# 3/3 [==============================] - 1s 564ms/step - loss: 9.2826e-05 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 1.0000
# Epoch 396/400
# 3/3 [==============================] - 1s 560ms/step - loss: 2.1291e-04 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 1.0000
# Epoch 397/400
# 3/3 [==============================] - 1s 579ms/step - loss: 3.6477e-04 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 1.0000
# Epoch 398/400
# 3/3 [==============================] - 1s 570ms/step - loss: 3.7654e-04 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 399/400
# 3/3 [==============================] - 1s 569ms/step - loss: 5.8409e-05 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 400/400
# 3/3 [==============================] - 1s 532ms/step - loss: 6.6181e-05 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0662 - accuracy: 0.9583
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FA4114B550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 129ms/step
# Fold 5 - Accuracy: 95.833%, F1 Score: 0.9583
# No.1 test score = 100.000 %, F1 Score = 1.0000
# No.2 test score = 100.000 %, F1 Score = 1.0000
# No.3 test score = 100.000 %, F1 Score = 1.0000
# No.4 test score = 100.000 %, F1 Score = 1.0000
# No.5 test score = 95.833 %, F1 Score = 0.9583
# average score = 99.167 %, average F1 Score = 0.9917
# Total processing time: 2434.51 seconds
